# %%
import pandas as pds
import numpy as np

# %%
df = pds.read_csv("data/GOLD_DATA_DUMP_PUBLIC_ONLY/BIOSAMPLE_DATA_TABLE.dsv", sep="\t")
# Out:
# /Users/wdduncan/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (13,14,16,18,19,23,26,27,28,29,30,34,35,36,37,39,41,42,43,44,45,52,57,62,70,72,73,76,77,78,79,86,98,99,100,103,104,105,106,111,119,124,133,134,135,142,144,146,149,165,191,208,229,233,252,253,254) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    BIOSAMPLE_ID                                     BIOSAMPLE_NAME  \
# 0        173480  Wine grape associated microbial communities fr...
# 1        173774  Fermented milk associated microbial communitie...
# 2        173775  Fermented milk associated microbial communitie...
# 3        173776  Fermented milk associated microbial communitie...
# 4        173784  Fermented milk associated microbial communitie...
#
#                           ADD_DATE                         MOD_DATE    MOD_BY  \
# 0  09-DEC-17 11.15.52.119000000 PM  05-JAN-18 12.58.38.000000000 PM  102151.0
# 1  09-DEC-17 11.36.30.369000000 PM  05-JAN-18 12.54.38.000000000 PM  102151.0
# 2  09-DEC-17 11.36.34.360000000 PM  05-JAN-18 12.54.43.000000000 PM  102151.0
# 3  09-DEC-17 11.36.38.315000000 PM  05-JAN-18 12.54.43.000000000 PM  102151.0
# 4  09-DEC-17 11.37.10.939000000 PM  05-JAN-18 12.54.43.000000000 PM  102151.0
#
#                                          DESCRIPTION        ECOSYSTEM  \
# 0  Wine grape associated microbial communities fr...  Host-associated
# 1  Fermented milk (koumiss) associated microbial ...       Engineered
# 2  Fermented milk (koumiss) associated microbial ...       Engineered
# 3  Fermented milk (koumiss) associated microbial ...       Engineered
# 4  Fermented milk (koumiss) associated microbial ...       Engineered
#
#   ECOSYSTEM_CATEGORY  ECOSYSTEM_TYPE ECOSYSTEM_SUBTYPE  ... DEPTH2 ALTITUDE  \
# 0             Plants    Phyllosphere       Caulosphere  ...    NaN      NaN
# 1    Food production  Dairy products               NaN  ...    NaN      NaN
# 2    Food production  Dairy products               NaN  ...    NaN      NaN
# 3    Food production  Dairy products               NaN  ...    NaN      NaN
# 4    Food production  Dairy products               NaN  ...    NaN      NaN
#
#    ALTITUDE2 SOLUBLE_IRON_MICROMOL BICARBONATE_MILLIMOL  H2S_MILLIMOL  \
# 0        NaN                   NaN                  NaN           NaN
# 1        NaN                   NaN                  NaN           NaN
# 2        NaN                   NaN                  NaN           NaN
# 3        NaN                   NaN                  NaN           NaN
# 4        NaN                   NaN                  NaN           NaN
#
#   H2S_PRESENT  IRRADIANCE OXYGEN_PRESENCE METHANE_CONC_MILLIMOL
# 0         NaN         NaN             NaN                   NaN
# 1         NaN         NaN             NaN                   NaN
# 2         NaN         NaN             NaN                   NaN
# 3         NaN         NaN             NaN                   NaN
# 4         NaN         NaN             NaN                   NaN
#
# [5 rows x 256 columns]

# %%
## find number of records
len(df)
# Out:
# 64144

# %%
## exclude columns that we don't care about
unwanted = ['BIOSAMPLE_ID', 'BIOSAMPLE_NAME', 'ADD_DATE', 'MOD_DATE', 'DESCRIPTION', 'ECOSYSTEM', 
            'ECOSYSTEM_CATEGORY', 'ECOSYSTEM_TYPE', 'ECOSYSTEM_SUBTYPE', 'SPECIFIC_ECOSYSTEM', 
            'PUBLIC_SP_COUNT', 'IS_TEST', 'ADMIN_DAP_COUNT', 'PUBLIC_AP_COUNT', 'ADMIN_SP_COUNT', 'MOD_BY',
            'ACTIVE', 'GOLD_ID', 'IS_PUBLIC', 'SUBMITTER_ID', 'PUBLIC_DAP_COUNT', 'ADMIN_AP_COUNT', 'SPECIMEN']
cols = [c for c in df.columns if c not in unwanted]

# %%
# cols
subdf = df[cols]

# %%
## get null counts
series = subdf.isnull().sum().sort_values()
countdf = pds.DataFrame({'field': series.index, 'null_count': series.values})

# %%
## get counts of non-nulls
countdf['non_null_count'] = len(df) - countdf.null_count

# %%
## get perecentage of nulls
countdf['percent_null'] = (countdf['null_count'] / countdf['non_null_count']) * 100
countdf['percent_null'] = \
    countdf['percent_null'].map(lambda x: "0%" if np.isinf(x) else "{0:.2f}%".format(x)) # format as percent

# %%
pds.set_option('display.max_rows', None)
countdf.sort_values(by=['non_null_count'], ascending=False)
# Out:
#                              field  null_count  non_null_count percent_null
# 0                ECOSYSTEM_PATH_ID         113           64031        0.18%
# 1                          HABITAT         498           63646        0.78%
# 2                         LOCATION         783           63361        1.24%
# 3                        COMMUNITY         847           63297        1.34%
# 4                 NCBI_TAXONOMY_ID        1091           63053        1.73%
# 5               NCBI_TAXONOMY_NAME        1128           63016        1.79%
# 6              GEOGRAPHIC_LOCATION        1491           62653        2.38%
# 7      SAMPLE_ISOLATION_COUNTRY_ID        2094           62050        3.37%
# 8                        LONGITUDE        4187           59957        6.98%
# 9                         LATITUDE        4187           59957        6.98%
# 10          SAMPLE_COLLECTION_SITE        4392           59752        7.35%
# 11                      IDENTIFIER        4909           59235        8.29%
# 12          SAMPLE_COLLECTION_YEAR       15062           49082       30.69%
# 15                       XLATITUDE       17908           46236       38.73%
# 16                   LATITUDE_TEST       17908           46236       38.73%
# 14                      XLONGITUDE       17908           46236       38.73%
# 13                  LONGITUDE_TEST       17908           46236       38.73%
# 17         SAMPLE_COLLECTION_MONTH       23476           40668       57.73%
# 18           SAMPLE_COLLECTION_DAY       24778           39366       62.94%
# 19                       HOST_NAME       35076           29068      120.67%
# 20                HOST_TAXONOMY_ID       35155           28989      121.27%
# 21             SAMPLE_CONTACT_NAME       47001           17143      274.17%
# 22                           DEPTH       47375           16769      282.52%
# 23            SAMPLE_CONTACT_EMAIL       48106           16038      299.95%
# 24                        ALTITUDE       50246           13898      361.53%
# 25                          XDEPTH       50972           13172      386.97%
# 26                      DEPTH_TEST       50972           13172      386.97%
# 27               HOST_BODY_PRODUCT       51551           12593      409.36%
# 28               LEGACY_DEPTH_DATA       51748           12396      417.46%
# 30                   ALTITUDE_TEST       52409           11735      446.60%
# 29                       XALTITUDE       52409           11735      446.60%
# 31                   HOST_COMMENTS       57729            6415      899.91%
# 32                      SAMPLE_OID       58219            5925      982.60%
# 33               TEMPERATURE_EXACT       60175            3969     1516.12%
# 34               LAT_LONG_INFERRED       60356            3788     1593.35%
# 35           NITRATE_CONCENTRATION       62068            2076     2989.79%
# 36                              PH       62118            2026     3066.04%
# 37               SAMPLING_STRATEGY       62139            2005     3099.20%
# 38            OXYGEN_CONCENTRATION       62146            1998     3110.41%
# 39                  HOST_BODY_SITE       62204            1940     3206.39%
# 40               TEMPERATURE_RANGE       62588            1556     4022.37%
# 41                 OXYGEN_PRESENCE       62759            1385     4531.34%
# 42                   WATER_SULFATE       62815            1329     4726.49%
# 43                  WATER_CHLORIDE       62838            1306     4811.49%
# 44                   WATER_CALCIUM       62887            1257     5002.94%
# 45                    WATER_SODIUM       62890            1254     5015.15%
# 46             SAMPLE_CONDUCTIVITY       63038            1106     5699.64%
# 47                        SALINITY       63094            1050     6008.95%
# 48                     H2S_PRESENT       63105            1039     6073.63%
# 49                        IS_DRAFT       63108            1036     6091.51%
# 50                WATER_ALKALINITY       63169             975     6478.87%
# 51          SALINITY_CONCENTRATION       63173             971     6505.97%
# 52       CHLOROPHYLL_CONCENTRATION       63208             936     6752.99%
# 53                     HOST_GENDER       63216             928     6812.07%
# 54               HOST_BODY_SUBSITE       63279             865     7315.49%
# 55                      IRRADIANCE       63315             829     7637.52%
# 56                 WATER_MAGNESIUM       63335             809     7828.80%
# 57                  LONGHURST_CODE       63359             785     8071.21%
# 58       SAMPLE_ISOLATION_COMMENTS       63365             779     8134.15%
# 59                             MRN       63373             771     8219.58%
# 60            PATIENT_VISIT_NUMBER       63380             764     8295.81%
# 61                    H2S_MILLIMOL       63454             690     9196.23%
# 62               GROWTH_CONDITIONS       63505             639     9938.18%
# 63                          DEPTH2       63510             634    10017.35%
# 64                     DEPTH2_TEST       63544             600    10590.67%
# 65                         XDEPTH2       63544             600    10590.67%
# 66                SUBSURFACE_DEPTH       63678             466    13664.81%
# 67           SUBMIT_BIOSAMPLE_NAME       63715             429    14851.98%
# 68                        PRESSURE       63739             405    15738.02%
# 69           SOLUBLE_IRON_MICROMOL       63775             369    17283.20%
# 70            PROPORT_WOA_SILICATE       63794             350    18226.86%
# 71           PROPORT_WOA_PHOSPHATE       63794             350    18226.86%
# 72           ITS_GROWTH_CONDITIONS       63820             324    19697.53%
# 73                  WATER_AMMONIUM       63827             317    20134.70%
# 74           METHANE_CONC_MILLIMOL       63829             315    20263.17%
# 75            BICARBONATE_MILLIMOL       63838             306    20862.09%
# 76                   WATER_DENSITY       63899             245    26081.22%
# 77              WATER_FLUORESCENCE       63936             208    30738.46%
# 78          SAMPLE_COLLECTION_HOUR       63962             182    35143.96%
# 79        SAMPLE_COLLECTION_MINUTE       63962             182    35143.96%
# 80           HOST_HEALTH_CONDITION       63964             180    35535.56%
# 81       WATER_DISS_CARBON_DIOXIDE       63981             163    39252.15%
# 82                        HOST_AGE       63990             154    41551.95%
# 83           WATER_REDOX_POTENTIAL       64022             122    52477.05%
# 84            HOST_BODY_PRODUCT_ID       64054              90    71171.11%
# 85                 OTHER_ECOSYSTEM       64071              73    87768.49%
# 86                     PROJECT_OID       64102              42   152623.81%
# 87                CRUISE_LINE_NAME       64103              41   156348.78%
# 89             ISOLATION_PUBMED_ID       64122              22   291463.64%
# 88        ISOLATION_PUBLICATION_ID       64122              22   291463.64%
# 90                   SAMPLE_VOLUME       64123              21   305347.62%
# 91                       HOST_RACE       64123              21   305347.62%
# 92                HOST_SPECIFICITY       64128              16   400800.00%
# 97           BIOGAS_FED_SUBSTRATES       64136               8   801700.00%
# 101             BIOGAS_TEMPERATURE       64136               8   801700.00%
# 99                  BIOGAS_VOA_TIC       64136               8   801700.00%
# 98   BIOGAS_TOTAL_INORGANIC_CARBON       64136               8   801700.00%
# 100             BIOGAS_ACETIC_ACID       64136               8   801700.00%
# 96           BIOGAS_RETENTION_TIME       64136               8   801700.00%
# 95   BIOGAS_VOLATILE_ORGANIC_ACIDS       64136               8   801700.00%
# 94                    BIOGAS_YIELD       64136               8   801700.00%
# 93              BIOGAS_METHANE_PCT       64136               8   801700.00%
# 102            BIOGAS_AMMONIUM_NH4       64137               7   916242.86%
# 103                HOST_MEDICATION       64137               7   916242.86%
# 104              HOST_BODY_SITE_ID       64140               4  1603500.00%
# 105                    ENV_PACKAGE       64142               2  3207100.00%
# 106      WATER_CARBON_NITROG_RATIO       64142               2  3207100.00%
# 107          WATER_SAMP_STORE_TEMP       64142               2  3207100.00%
# 121           HOST_BODY_SUBSITE_ID       64143               1  6414300.00%
# 120                      ELEVATION       64143               1  6414300.00%
# 119             SOIL_CURR_LAND_USE       64143               1  6414300.00%
# 118           SOIL_CURR_VEGETATION       64143               1  6414300.00%
# 117    SOIL_CURR_VEGETATION_METHOD       64143               1  6414300.00%
# 115                   SOIL_TEXTURE       64143               1  6414300.00%
# 116                   SOIL_HORIZON       64143               1  6414300.00%
# 114                   TOT_NITROGEN       64143               1  6414300.00%
# 112           WATER_SAMP_STORE_LOC       64143               1  6414300.00%
# 111                   SOIL_SIEVING       64143               1  6414300.00%
# 110             SOIL_WATER_CONTENT       64143               1  6414300.00%
# 109          SAMPLE_WEIGHT_DNA_EXT       64143               1  6414300.00%
# 108           WATER_MISC_PARAMETER       64143               1  6414300.00%
# 113                  SOIL_FLOODING       64143               1  6414300.00%
# 197           PROPORT_WOA_SALINITY       64144               0           0%
# 193                BIOGAS_METHANOL       64144               0           0%
# 194                BIOGAS_PROPANOL       64144               0           0%
# 195                 BIOGAS_ETHANOL       64144               0           0%
# 196                 BIOGAS_BUTANOL       64144               0           0%
# 201           SOIL_LINK_CLASS_INFO       64144               0           0%
# 198                     XALTITUDE2       64144               0           0%
# 199        SOIL_ANNUAL_SEASON_TEMP       64144               0           0%
# 200      SOIL_ANNUAL_SEASON_PRECPT       64144               0           0%
# 191          BIOGAS_ISO_BUTYL_ACID       64144               0           0%
# 202    WATER_BACTERIAL_CARBON_PROD       64144               0           0%
# 192              BIOGAS_BUTYL_ACID       64144               0           0%
# 187        PROPORT_WOA_TEMPERATURE       64144               0           0%
# 190            BIOGAS_VALERIC_ACID       64144               0           0%
# 189        BIOGAS_ISO_VALERIC_ACID       64144               0           0%
# 188          BIOGAS_PROPIONIC_ACID       64144               0           0%
# 204           WATER_BACTERIAL_PROD       64144               0           0%
# 186             GROWTH_TEMPERATURE       64144               0           0%
# 185                PROPORT_STATION       64144               0           0%
# 184              PROPORT_ISOLATION       64144               0           0%
# 183         SOIL_LINK_CLIMATE_INFO       64144               0           0%
# 182                  PROPORT_OCEAN       64144               0           0%
# 181                 ALTITUDE2_TEST       64144               0           0%
# 180                     ELEVATION2       64144               0           0%
# 179             SOIL_PREV_LAND_USE       64144               0           0%
# 203           WATER_BACTERIAL_RESP       64144               0           0%
# 207           WATER_ALKYL_DIETHERS       64144               0           0%
# 205         WATER_ATMOSPHERIC_DATA       64144               0           0%
# 206            WATER_AMINOPEPT_ACT       64144               0           0%
# 231                  WATER_BROMIDE       64144               0           0%
# 230                 SOIL_FAO_CLASS       64144               0           0%
# 229               SOIL_LOCAL_CLASS       64144               0           0%
# 228        SOIL_LOCAL_CLASS_METHOD       64144               0           0%
# 227                      SOIL_TYPE       64144               0           0%
# 226               SOIL_TYPE_METHOD       64144               0           0%
# 225            SOIL_SLOPE_GRADIENT       64144               0           0%
# 224              SOIL_SLOPE_ASPECT       64144               0           0%
# 223          SOIL_PROFILE_POSITION       64144               0           0%
# 222            SOIL_DRAINAGE_CLASS       64144               0           0%
# 221            SOIL_TEXTURE_METHOD       64144               0           0%
# 220                 SOIL_PH_METHOD       64144               0           0%
# 219                 TOT_ORG_CARBON       64144               0           0%
# 218          SOIL_TOT_ORG_C_METHOD       64144               0           0%
# 217              SOIL_TOT_N_METHOD       64144               0           0%
# 216         SOIL_MICROBIAL_BIOMASS       64144               0           0%
# 215  SOIL_MICROBIAL_BIOMASS_METHOD       64144               0           0%
# 214         SOIL_LINK_ADDIT_ANALYS       64144               0           0%
# 213           SOIL_SALINITY_METHOD       64144               0           0%
# 212            PROPORT_WOA_NITRATE       64144               0           0%
# 211       SOIL_HEAVY_METALS_METHOD       64144               0           0%
# 210             SOIL_ALUMINIUM_SAT       64144               0           0%
# 209      SOIL_ALUMINIUM_SAT_METHOD       64144               0           0%
# 208                SOIL_MISC_PARAM       64144               0           0%
# 177             SOIL_CROP_ROTATION       64144               0           0%
# 178        SOIL_PREV_LAND_USE_METH       64144               0           0%
# 174             SOIL_EXTREME_EVENT       64144               0           0%
# 176                   SOIL_TILLAGE       64144               0           0%
# 134             WATER_DOWNWARD_PAR       64144               0           0%
# 145                  WATER_CURRENT       64144               0           0%
# 144                      ALTITUDE2       64144               0           0%
# 143                 SAMPLE_BIOMASS       64144               0           0%
# 142               REPLICATE_NUMBER       64144               0           0%
# 141           WATER_ORGANISM_COUNT       64144               0           0%
# 140   PROPORT_WOA_DISSOLVED_OXYGEN       64144               0           0%
# 139               WATER_ORG_MATTER       64144               0           0%
# 138          WATER_LIGHT_INTENSITY       64144               0           0%
# 137          WATER_DISS_ORG_CARBON       64144               0           0%
# 136    WATER_DISS_INORG_PHOSPHORUS       64144               0           0%
# 135         WATER_DISS_INORG_NITRO       64144               0           0%
# 133                  WATER_NITRITE       64144               0           0%
# 147          WATER_TOT_PART_CARBON       64144               0           0%
# 132        WATER_DISS_INORG_CARBON       64144               0           0%
# 131     WATER_GLUCOSIDASE_ACTIVITY       64144               0           0%
# 130            WATER_DISS_HYDROGEN       64144               0           0%
# 129                     JPA_ENTITY       64144               0           0%
# 128           WATER_DIETHER_LIPIDS       64144               0           0%
# 127           WATER_MEAN_FRICT_VEL       64144               0           0%
# 126      WATER_MEAN_PEAK_FRICT_VEL       64144               0           0%
# 125                    OTHER_HOSTS       64144               0           0%
# 124                WATER_N_ALKANES       64144               0           0%
# 123      WATER_CHEM_ADMINISTRATION       64144               0           0%
# 122        WATER_DISS_ORG_NITROGEN       64144               0           0%
# 146           WATER_TOT_PHOSPHORUS       64144               0           0%
# 148          WATER_TOT_INORG_NITRO       64144               0           0%
# 175                      SOIL_FIRE       64144               0           0%
# 162             WATER_PERTURBATION       64144               0           0%
# 173            SOIL_HORIZON_METHOD       64144               0           0%
# 172   SOIL_WATER_CONTENT_SOIL_METH       64144               0           0%
# 171         SOIL_POOL_DNA_EXTRACTS       64144               0           0%
# 170         SOIL_STORAGE_CONDITION       64144               0           0%
# 169           WATER_BISHOMOHOPANOL       64144               0           0%
# 168              SOIL_HEAVY_METALS       64144               0           0%
# 167                KNOWN_NON_HOSTS       64144               0           0%
# 166      WATER_SOLUBLE_REACT_PHOSP       64144               0           0%
# 165          WATER_OXY_STAT_SAMPLE       64144               0           0%
# 164          WATER_PART_ORG_CARBON       64144               0           0%
# 163        WATER_PART_ORG_NITROGEN       64144               0           0%
# 161    WATER_PETROLEUM_HYDROCARBON       64144               0           0%
# 149           WATER_TOT_DISS_NITRO       64144               0           0%
# 160            WATER_PHAEOPIGMENTS       64144               0           0%
# 159     WATER_PHOSPLIPID_FATT_ACID       64144               0           0%
# 158              WATER_PHOTON_FLUX       64144               0           0%
# 157                WATER_POTASSIUM       64144               0           0%
# 156             WATER_PRIMARY_PROD       64144               0           0%
# 155           WATER_SAMP_STORE_DUR       64144               0           0%
# 154                  WATER_SULFIDE       64144               0           0%
# 153             WATER_ORG_NITROGEN       64144               0           0%
# 152      WATER_SUSPEND_PART_MATTER       64144               0           0%
# 151              WATER_TIDAL_STAGE       64144               0           0%
# 150      WATER_TOT_DEPTH_WATER_COL       64144               0           0%
# 232         SOIL_AGROCHEM_ADDITION       64144               0           0%
